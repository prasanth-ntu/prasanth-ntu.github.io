# %%
# %matplotlib inline

import matplotlib.pyplot as plt
import numpy as np

# %%
x = np.linspace(0, 10, 100)
fig = plt.figure()
plt.plot(x, np.sin(x), '-')
plt.plot(x, np.cos(x), '--')

plt.show()
fig.savefig('my_figure.png')

# %%
# !dir
# Out:
#  Volume in drive C is Acer
#  Volume Serial Number is 9860-C64E
#
#  Directory of C:\Users\User\Desktop\Module 1a - Foundations of Data Science in Python\Module 1a - Foundations of Data Science in Python\Week 3 Exploratory Data Analysis
#
# 周四/10/19/2017  23:53    <DIR>          .
# 周四/10/19/2017  23:53    <DIR>          ..
# 周一/10/02/2017  02:20    <DIR>          .ipynb_checkpoints
# 周一/10/02/2017  14:56           856,773 marathon-data.csv
# 周四/10/19/2017  23:53            22,604 my_figure.png
# 周四/10/19/2017  23:46           796,102 practice_matplotlib.ipynb
# 周一/10/02/2017  02:20    <DIR>          res
# 周一/10/02/2017  02:20            55,658 Titanic.csv
# 周四/10/19/2017  23:53           981,629 Week3_Exploratory_Data_Analysis.ipynb
#                5 File(s)      2,712,766 bytes
#                4 Dir(s)  204,554,006,528 bytes free

# %%
from IPython.display import Image
Image('my_figure.png')

# %%
fig.canvas.get_supported_filetypes()
# Out:
# {'eps': 'Encapsulated Postscript',
#  'pdf': 'Portable Document Format',
#  'pgf': 'PGF code for LaTeX',
#  'png': 'Portable Network Graphics',
#  'ps': 'Postscript',
#  'raw': 'Raw RGBA bitmap',
#  'rgba': 'Raw RGBA bitmap',
#  'svg': 'Scalable Vector Graphics',
#  'svgz': 'Scalable Vector Graphics'}

# %%
plt.style.use('seaborn-whitegrid')

# %%
fig = plt.figure()
ax = plt.axes()

x = np.linspace(0, 10, 100)
ax.plot(x, np.sin(x));
ax.plot(x, np.cos(x));

# %% [markdown]
# ### Adjusting line colors

# %%
plt.plot(x, np.sin(x - 0), color='blue')          # specify color by name
plt.plot(x, np.sin(x - 1), color='g')             # short color code (rgbcmyk)
plt.plot(x, np.sin(x - 2), color='0.75')          # grayscale between 0 and 1
plt.plot(x, np.sin(x - 3), color='#FFDD44')       # Hex code (RRGGBB from 00 to FF)
plt.plot(x, np.sin(x - 4), color=(1.0, 0.2, 0.3)) # RGB tuple, values between 0 and 1
plt.plot(x, np.sin(x - 5), color='chartreuse')    # all HTML color names supported

# %% [markdown]
# ### Adjusting the line style

# %%
plt.plot(x, x + 0, linestyle='solid')
plt.plot(x, x + 1, linestyle='dashed')
plt.plot(x, x + 2, linestyle='dashdot')
plt.plot(x, x + 3, linestyle='dotted')

plt.plot(x, x + 4, linestyle='-')
plt.plot(x, x + 5, linestyle='--')
plt.plot(x, x + 6, linestyle='-.')
plt.plot(x, x + 7, linestyle=':');

# %%
plt.plot(x, np.sin(x))
#plt.axis([-1, 11, -1.5, 1.5])
#plt.axis('tight');
plt.axis('equal');

plt.title('A Sine wave')
plt.xlabel('x')
plt.ylabel('y');

# %%
plt.plot(x, np.sin(x), '-g', label='sin(x)')
plt.plot(x, np.cos(x), ':b', label='cos(x)')
plt.axis('equal')
plt.legend();

# %% [markdown]
# ### Simple Scatter Plots

# %%
x = np.linspace(0, 10, 30)
y = np.sin(x)

plt.plot(x, y, 'o', color='black')

# %%
# a number of common symbols
rng = np.random.RandomState(0)
for marker in ['o', '.', ',', 'x', '+', 'v', '^', '<', '>', 's', 'd']:
    plt.plot(rng.rand(5), rng.rand(5), marker, label="marker='{0}'".format(marker))
plt.legend(numpoints=1)
plt.xlim(0, 1.8)
# Out:
# (0, 1.8)

# %%
plt.plot(x, y, '-ok');  # '-' solid line, 'o' circle marker, 'k' color black

# %%
plt.plot(x, y, '-p', color='gray', 
         markersize=15, linewidth=4,
         markerfacecolor='white',
         markeredgecolor='gray',
         markeredgewidth=2)
plt.ylim(-1.2, 1.2);

# %%
plt.scatter(x, y, marker='o');

# %%
rng = np.random.RandomState(0)
x = rng.randn(100)
y = rng.randn(100)
colors = rng.rand(100)
sizes = 1000 * rng.rand(100)
plt.scatter(x, y, c=colors, s=sizes, alpha=0.3, cmap='viridis')
plt.colorbar();

# %% [markdown]
# ### Density and Contour Plots

# %%
plt.style.use('seaborn-white')

# %%
def f(x, y):
    return np.sin(x) ** 10 + np.cos(10 + x * y) * np.cos(x)

# %%
x = np.linspace(0, 5, 100)
y = np.linspace(0, 5, 100)

X, Y = np.meshgrid(x, y)
Z = f(X, Y)

#plt.contour(X, Y, Z, colors='black');
# When single color is used, negative values are represented by dashed lines and positive values by solid lines
plt.contourf(X, Y, Z, 20, cmap='RdGy'); # 'RdGy' short for Red-Gray
plt.colorbar();

# %%
# Continuous color plot
plt.imshow(Z, extent=[0, 5, 0, 5], origin='lower', cmap='RdGy')
plt.colorbar()
plt.axis(aspect='image')
# Out:
# (0.0, 5.0, 0.0, 5.0)

# %%
# Combination of imshow and contour
contours = plt.contour(X, Y, Z, 3, colors='black')
plt.clabel(contours, inline=True, fontsize=8)
plt.imshow(Z, extent=[0, 5, 0, 5,], origin='lower', cmap='RdGy', alpha=0.5)
plt.colorbar();

# %% [markdown]
# ### Histograms

# %%
data = np.random.randn(1000)
plt.hist(data);

# %%
plt.hist(data, bins=30, normed=True, alpha=0.5, histtype='stepfilled', color='steelblue', edgecolor='none');

# %%
# comparing histograms of several distributions
x1 = np.random.normal(0, 0.8, 1000)
x2 = np.random.normal(-2, 1, 1000)
x3 = np.random.normal(3, 2, 1000)

kwargs = dict(histtype='stepfilled', alpha=0.3, normed=True, bins=40)
plt.hist(x1, **kwargs);
plt.hist(x2, **kwargs);
plt.hist(x3, **kwargs);

# %% [markdown]
# ### Three dimensional plotting

# %%
from mpl_toolkits import mplot3d
# %matplotlib notebook
# change to interactive fugures instead of inline static figures

# %%
fig = plt.figure()
ax = plt.axes(projection='3d')
